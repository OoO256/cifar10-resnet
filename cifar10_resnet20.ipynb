# %% [markdown]
# <a href="https://colab.research.google.com/github/OoO256/cifar10-resnet/blob/master/cifar10_resnet20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 150
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 22s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 130:
        lr *= 0.5e-3
    elif epoch > 110:
        lr *= 1e-3
    elif epoch > 80:
        lr *= 1e-2
    elif epoch > 50:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 16)   0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           conv2d_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 32)   0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           conv2d_17[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=0, workers=4,
                        callbacks=callbacks,
                        steps_per_epoch= x_train.shape[0] // batch_size,)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Learning rate:  0.001
#
# Epoch 00001: val_acc improved from -inf to 0.40360, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Learning rate:  0.001
#
# Epoch 00002: val_acc improved from 0.40360 to 0.64530, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Learning rate:  0.001
#
# Epoch 00003: val_acc did not improve from 0.64530
# Learning rate:  0.001
#
# Epoch 00004: val_acc improved from 0.64530 to 0.67570, saving model to /content/saved_models/cifar10_ResNet20v1_model.004.h5
# Learning rate:  0.001
#
# Epoch 00005: val_acc improved from 0.67570 to 0.72200, saving model to /content/saved_models/cifar10_ResNet20v1_model.005.h5
# Learning rate:  0.001
#
# Epoch 00006: val_acc improved from 0.72200 to 0.77260, saving model to /content/saved_models/cifar10_ResNet20v1_model.006.h5
# Learning rate:  0.001
#
# Epoch 00007: val_acc did not improve from 0.77260
# Learning rate:  0.001
#
# Epoch 00008: val_acc did not improve from 0.77260
# Learning rate:  0.001
#
# Epoch 00009: val_acc did not improve from 0.77260
# Learning rate:  0.001
#
# Epoch 00010: val_acc improved from 0.77260 to 0.80460, saving model to /content/saved_models/cifar10_ResNet20v1_model.010.h5
# Learning rate:  0.001
#
# Epoch 00011: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00012: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00013: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00014: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00015: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00016: val_acc did not improve from 0.80460
# Learning rate:  0.001
#
# Epoch 00017: val_acc improved from 0.80460 to 0.80720, saving model to /content/saved_models/cifar10_ResNet20v1_model.017.h5
# Learning rate:  0.001
#
# Epoch 00018: val_acc did not improve from 0.80720
# Learning rate:  0.001
#
# Epoch 00019: val_acc did not improve from 0.80720
# Learning rate:  0.001
#
# Epoch 00020: val_acc did not improve from 0.80720
# Learning rate:  0.001
#
# Epoch 00021: val_acc improved from 0.80720 to 0.81470, saving model to /content/saved_models/cifar10_ResNet20v1_model.021.h5
# Learning rate:  0.001
#
# Epoch 00022: val_acc did not improve from 0.81470
# Learning rate:  0.001
#
# Epoch 00023: val_acc did not improve from 0.81470
# Learning rate:  0.001
#
# Epoch 00024: val_acc did not improve from 0.81470
# Learning rate:  0.001
#
# Epoch 00025: val_acc improved from 0.81470 to 0.81770, saving model to /content/saved_models/cifar10_ResNet20v1_model.025.h5
# Learning rate:  0.001
#
# Epoch 00026: val_acc did not improve from 0.81770
# Learning rate:  0.001
#
# Epoch 00027: val_acc did not improve from 0.81770
# Learning rate:  0.001
#
# Epoch 00028: val_acc improved from 0.81770 to 0.82720, saving model to /content/saved_models/cifar10_ResNet20v1_model.028.h5
# Learning rate:  0.001
#
# Epoch 00029: val_acc improved from 0.82720 to 0.83220, saving model to /content/saved_models/cifar10_ResNet20v1_model.029.h5
# Learning rate:  0.001
#
# Epoch 00030: val_acc improved from 0.83220 to 0.84050, saving model to /content/saved_models/cifar10_ResNet20v1_model.030.h5
# Learning rate:  0.001
#
# Epoch 00031: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00032: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00033: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00034: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00035: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00036: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00037: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00038: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00039: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00040: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00041: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00042: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00043: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00044: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00045: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00046: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00047: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00048: val_acc did not improve from 0.84050
# Learning rate:  0.001
#
# Epoch 00049: val_acc improved from 0.84050 to 0.85760, saving model to /content/saved_models/cifar10_ResNet20v1_model.049.h5
# Learning rate:  0.001
#
# Epoch 00050: val_acc did not improve from 0.85760
# Learning rate:  0.001
#
# Epoch 00051: val_acc did not improve from 0.85760
# Learning rate:  0.0001
#
# Epoch 00052: val_acc improved from 0.85760 to 0.89690, saving model to /content/saved_models/cifar10_ResNet20v1_model.052.h5
# Learning rate:  0.0001
#
# Epoch 00053: val_acc improved from 0.89690 to 0.89830, saving model to /content/saved_models/cifar10_ResNet20v1_model.053.h5
# Learning rate:  0.0001
#
# Epoch 00054: val_acc did not improve from 0.89830
# Learning rate:  0.0001
#
# Epoch 00055: val_acc improved from 0.89830 to 0.89960, saving model to /content/saved_models/cifar10_ResNet20v1_model.055.h5
# Learning rate:  0.0001
#
# Epoch 00056: val_acc improved from 0.89960 to 0.90000, saving model to /content/saved_models/cifar10_ResNet20v1_model.056.h5
# Learning rate:  0.0001
#
# Epoch 00057: val_acc improved from 0.90000 to 0.90230, saving model to /content/saved_models/cifar10_ResNet20v1_model.057.h5
# Learning rate:  0.0001
#
# Epoch 00058: val_acc improved from 0.90230 to 0.90360, saving model to /content/saved_models/cifar10_ResNet20v1_model.058.h5
# Learning rate:  0.0001
#
# Epoch 00059: val_acc did not improve from 0.90360
# Learning rate:  0.0001
#
# Epoch 00060: val_acc did not improve from 0.90360
# Learning rate:  0.0001
#
# Epoch 00061: val_acc improved from 0.90360 to 0.90480, saving model to /content/saved_models/cifar10_ResNet20v1_model.061.h5
# Learning rate:  0.0001
#
# Epoch 00062: val_acc did not improve from 0.90480
# Learning rate:  0.0001
#
# Epoch 00063: val_acc did not improve from 0.90480
# Learning rate:  0.0001
#
# Epoch 00064: val_acc did not improve from 0.90480
# Learning rate:  0.0001
#
# Epoch 00065: val_acc improved from 0.90480 to 0.90570, saving model to /content/saved_models/cifar10_ResNet20v1_model.065.h5
# Learning rate:  0.0001
#
# Epoch 00066: val_acc did not improve from 0.90570
# Learning rate:  0.0001
#
# Epoch 00067: val_acc did not improve from 0.90570
# Learning rate:  0.0001
#
# Epoch 00068: val_acc did not improve from 0.90570
# Learning rate:  0.0001
#
# Epoch 00069: val_acc improved from 0.90570 to 0.90620, saving model to /content/saved_models/cifar10_ResNet20v1_model.069.h5
# Learning rate:  0.0001
#
# Epoch 00070: val_acc did not improve from 0.90620
# Learning rate:  0.0001
#
# Epoch 00071: val_acc did not improve from 0.90620
# Learning rate:  0.0001
#
# Epoch 00072: val_acc did not improve from 0.90620
# Learning rate:  0.0001
#
# Epoch 00073: val_acc improved from 0.90620 to 0.90790, saving model to /content/saved_models/cifar10_ResNet20v1_model.073.h5
# Learning rate:  0.0001
#
# Epoch 00074: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00075: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00076: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00077: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00078: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00079: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00080: val_acc did not improve from 0.90790
# Learning rate:  0.0001
#
# Epoch 00081: val_acc did not improve from 0.90790
# Learning rate:  1e-05
#
# Epoch 00082: val_acc improved from 0.90790 to 0.90810, saving model to /content/saved_models/cifar10_ResNet20v1_model.082.h5
# Learning rate:  1e-05
#
# Epoch 00083: val_acc did not improve from 0.90810
# Learning rate:  1e-05
#
# Epoch 00084: val_acc improved from 0.90810 to 0.90890, saving model to /content/saved_models/cifar10_ResNet20v1_model.084.h5
# Learning rate:  1e-05
#
# Epoch 00085: val_acc improved from 0.90890 to 0.91000, saving model to /content/saved_models/cifar10_ResNet20v1_model.085.h5
# Learning rate:  1e-05
#
# Epoch 00086: val_acc improved from 0.91000 to 0.91020, saving model to /content/saved_models/cifar10_ResNet20v1_model.086.h5
# Learning rate:  1e-05
#
# Epoch 00087: val_acc did not improve from 0.91020
# Learning rate:  1e-05
#
# Epoch 00088: val_acc did not improve from 0.91020
# Learning rate:  1e-05
#
# Epoch 00089: val_acc did not improve from 0.91020
# Learning rate:  1e-05
#
# Epoch 00090: val_acc improved from 0.91020 to 0.91080, saving model to /content/saved_models/cifar10_ResNet20v1_model.090.h5
# Learning rate:  1e-05
#
# Epoch 00091: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00092: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00093: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00094: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00095: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00096: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00097: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00098: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00099: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00100: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00101: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00102: val_acc did not improve from 0.91080
# Learning rate:  1e-05
#
# Epoch 00103: val_acc improved from 0.91080 to 0.91190, saving model to /content/saved_models/cifar10_ResNet20v1_model.103.h5
# Learning rate:  1e-05
#
# Epoch 00104: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00105: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00106: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00107: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00108: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00109: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00110: val_acc did not improve from 0.91190
# Learning rate:  1e-05
#
# Epoch 00111: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00112: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00113: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00114: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00115: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00116: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00117: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00118: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00119: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00120: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00121: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00122: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00123: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00124: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00125: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00126: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00127: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00128: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00129: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00130: val_acc did not improve from 0.91190
# Learning rate:  1e-06
#
# Epoch 00131: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00132: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00133: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00134: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00135: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00136: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00137: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00138: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00139: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00140: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00141: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00142: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00143: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00144: val_acc did not improve from 0.91190
# Learning rate:  5e-07
#
# Epoch 00145: val_acc improved from 0.91190 to 0.91210, saving model to /content/saved_models/cifar10_ResNet20v1_model.145.h5
# Learning rate:  5e-07
#
# Epoch 00146: val_acc did not improve from 0.91210
# Learning rate:  5e-07
#
# Epoch 00147: val_acc did not improve from 0.91210
# Learning rate:  5e-07
#
# Epoch 00148: val_acc did not improve from 0.91210
# Learning rate:  5e-07
#
# Epoch 00149: val_acc did not improve from 0.91210
# Learning rate:  5e-07
#
# Epoch 00150: val_acc did not improve from 0.91210
# 10000/10000 [==============================] - 1s 140us/step
# Test loss: 0.44311357316970823
# Test accuracy: 0.911

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
